# %% [markdown]
# # QOSF Task 3
#
# I need to build an interpreter for QASM 3.
# Framework used : Cirq

# %%
# !pip install cirq  ply
# Out:
# Requirement already satisfied: cirq in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (0.12.0)
# Requirement already satisfied: ply in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (3.11)
# Requirement already satisfied: cirq-ionq==0.12.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq) (0.12.0)
# Requirement already satisfied: cirq-rigetti==0.12.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq) (0.12.0)
# Requirement already satisfied: cirq-pasqal==0.12.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq) (0.12.0)
# Requirement already satisfied: cirq-web==0.12.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq) (0.12.0)
# Requirement already satisfied: cirq-google==0.12.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq) (0.12.0)
# Requirement already satisfied: cirq-core==0.12.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq) (0.12.0)
# Requirement already satisfied: cirq-aqt==0.12.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq) (0.12.0)
# Requirement already satisfied: requests~=2.18 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-aqt==0.12.0->cirq) (2.26.0)
# Requirement already satisfied: matplotlib~=3.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-core==0.12.0->cirq) (3.4.3)
# Requirement already satisfied: sortedcontainers~=2.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-core==0.12.0->cirq) (2.4.0)
# Requirement already satisfied: tqdm in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-core==0.12.0->cirq) (4.62.2)
# Requirement already satisfied: typing-extensions in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-core==0.12.0->cirq) (3.10.0.0)
# Requirement already satisfied: pandas in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-core==0.12.0->cirq) (1.3.2)
# Requirement already satisfied: scipy in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-core==0.12.0->cirq) (1.7.1)
# Requirement already satisfied: numpy~=1.16 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-core==0.12.0->cirq) (1.21.2)
# Requirement already satisfied: networkx~=2.4 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-core==0.12.0->cirq) (2.6.2)
# Requirement already satisfied: sympy in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-core==0.12.0->cirq) (1.8)
# Requirement already satisfied: protobuf~=3.13.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-google==0.12.0->cirq) (3.13.0)
# Requirement already satisfied: google-api-core[grpc]<2.0.0dev,>=1.14.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-google==0.12.0->cirq) (1.31.2)
# Requirement already satisfied: sniffio~=1.2.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (1.2.0)
# Requirement already satisfied: python-dateutil~=2.8.1 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (2.8.2)
# Requirement already satisfied: iso8601~=0.1.14 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (0.1.16)
# Requirement already satisfied: httpcore~=0.11.1 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (0.11.1)
# Requirement already satisfied: h11~=0.9.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (0.9.0)
# Requirement already satisfied: toml~=0.10.2 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (0.10.2)
# Requirement already satisfied: retrying~=1.3.3 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (1.3.3)
# Requirement already satisfied: pyjwt~=1.7.1 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (1.7.1)
# Requirement already satisfied: idna~=2.10 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (2.10)
# Requirement already satisfied: httpx~=0.15.5 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (0.15.5)
# Requirement already satisfied: pydantic~=1.8.2 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (1.8.2)
# Collecting attrs~=20.3.0
#   Using cached attrs-20.3.0-py2.py3-none-any.whl (49 kB)
# Requirement already satisfied: six~=1.16.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (1.16.0)
# Requirement already satisfied: qcs-api-client~=0.8.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (0.8.0)
# Requirement already satisfied: pyquil~=3.0.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (3.0.0)
# Requirement already satisfied: rfc3339~=6.2 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (6.2)
# Requirement already satisfied: rfc3986~=1.5.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (1.5.0)
# Requirement already satisfied: certifi~=2021.5.30 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from cirq-rigetti==0.12.0->cirq) (2021.5.30)
# Requirement already satisfied: setuptools>=40.3.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==0.12.0->cirq) (57.4.0)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==0.12.0->cirq) (1.35.0)
# Requirement already satisfied: packaging>=14.3 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==0.12.0->cirq) (21.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==0.12.0->cirq) (1.53.0)
# Requirement already satisfied: pytz in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==0.12.0->cirq) (2021.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.29.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==0.12.0->cirq) (1.39.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==0.12.0->cirq) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==0.12.0->cirq) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==0.12.0->cirq) (0.2.8)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from matplotlib~=3.0->cirq-core==0.12.0->cirq) (8.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from matplotlib~=3.0->cirq-core==0.12.0->cirq) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from matplotlib~=3.0->cirq-core==0.12.0->cirq) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from matplotlib~=3.0->cirq-core==0.12.0->cirq) (1.3.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core[grpc]<2.0.0dev,>=1.14.0->cirq-google==0.12.0->cirq) (0.4.8)
# Requirement already satisfied: rpcq<4.0.0,>=3.6.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from pyquil~=3.0.0->cirq-rigetti==0.12.0->cirq) (3.9.2)
# Requirement already satisfied: lark<0.12.0,>=0.11.1 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from pyquil~=3.0.0->cirq-rigetti==0.12.0->cirq) (0.11.3)
# Requirement already satisfied: retry<0.10.0,>=0.9.2 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from pyquil~=3.0.0->cirq-rigetti==0.12.0->cirq) (0.9.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from requests~=2.18->cirq-aqt==0.12.0->cirq) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from requests~=2.18->cirq-aqt==0.12.0->cirq) (2.0.4)
# Requirement already satisfied: decorator>=3.4.2 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from retry<0.10.0,>=0.9.2->pyquil~=3.0.0->cirq-rigetti==0.12.0->cirq) (5.0.9)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from retry<0.10.0,>=0.9.2->pyquil~=3.0.0->cirq-rigetti==0.12.0->cirq) (1.10.0)
# Requirement already satisfied: python-rapidjson in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from rpcq<4.0.0,>=3.6.0->pyquil~=3.0.0->cirq-rigetti==0.12.0->cirq) (1.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from rpcq<4.0.0,>=3.6.0->pyquil~=3.0.0->cirq-rigetti==0.12.0->cirq) (22.2.1)
# Requirement already satisfied: ruamel.yaml in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from rpcq<4.0.0,>=3.6.0->pyquil~=3.0.0->cirq-rigetti==0.12.0->cirq) (0.17.14)
# Requirement already satisfied: msgpack<1.0,>=0.6 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from rpcq<4.0.0,>=3.6.0->pyquil~=3.0.0->cirq-rigetti==0.12.0->cirq) (0.6.2)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from ruamel.yaml->rpcq<4.0.0,>=3.6.0->pyquil~=3.0.0->cirq-rigetti==0.12.0->cirq) (0.2.6)
# Requirement already satisfied: mpmath>=0.19 in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from sympy->cirq-core==0.12.0->cirq) (1.2.1)
# Requirement already satisfied: colorama in c:\users\abhishek mittal\anaconda3\envs\cirq_work\lib\site-packages (from tqdm->cirq-core==0.12.0->cirq) (0.4.4)
# Installing collected packages: attrs
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.2.0
#     Uninstalling attrs-21.2.0:
#       Successfully uninstalled attrs-21.2.0
# Successfully installed attrs-20.3.0

# %%
# Libraries used 
from ply import lex, yacc
import numpy as np 
import cirq
from typing import Optional
from cirq import ops, Circuit, NamedQubit, CX
from typing import Any, Callable, cast, Dict, Iterable, List, Optional, Sequence, Union
import re
import functools
from cirq import Simulator 
sim=Simulator()
from cirq.circuits.qasm_output import QasmUGate

# %% [markdown]
# # Process
#
# Step 1: Build a Lexer that can break down the program into known tokens \
# Step 2: Build a Parser that can take these tokens and perform the required operations on them  \
# Step 3: Test the Parser

# %% [markdown]
# # Lexer
#
# I have created a class for the Lexer that will take the OpenQASM 3 program and break it down into tokens.

# %%
class OPENQASMLexer:
    def __init__(self):
        self.lex = lex.lex(object=self,debug=False)

    literals = ['{','}','[',']','(',')',';',',','+','/','*','-','^']

    reserved = {
        'qubit':'QUBIT',
        'bit':'BIT',
        'measure':'MEASURE'
    }

    tokens = [
        'FORMAT_SPEC',
        'NUMBER',
        'NATURAL_NUMBER',
        'STDGATES',
        'ID',
        'PI',
    ]   + list(reserved.values())

    t_ignore = " \t"

    def t_COMMENT(self,t):
        r"""//.*"""
        print(t.value)
        pass

    def t_FORMAT_SPEC(self,t):
        r"""OPENQASM(\s+)([^\s\t\;]*);"""
        match = re.match(r"""OPENQASM(\s+)([^\s\t;]*);""", t.value)
        t.value = match.groups()[1]
        return t
    
    def t_NUMBER(self, t):
        r"""(
        (
        [0-9]+\.?|
        [0-9]?\.[0-9]+
        )
        [eE][+-]?[0-9]+
        )|
        (
        ([0-9]+)?\.[0-9]+|
        [0-9]+\.)"""
        t.value = float(t.value)
        return t

    def t_NATURAL_NUMBER(self, t):
        r"""\d+"""
        t.value = int(t.value)
        return t
    
    def t_newline(self,t):
        r'\n+'
        t.lexer.lineno += len(t.value)
        
    def t_STDGATES(self,t):
        r"""include(\s+)"stdgates.inc";"""
        print("\ninclude file encountered")
        return t
    
    def t_QUBIT(self,t):
        r"""qubit"""
        return t
    
    def t_BIT(self,t):
        r"""bit"""
        return t

    def t_ID(self,t):
        r"""[a-zA-Z][a-zA-Z\d_]*"""
        return t

    def t_MEASURE(self, t):
        r"""measure"""
        return t

    def t_ARROW(self, t):
        """->"""
        return t
    
    def t_PI(self, t):
        r"""pi"""
        t.value = np.pi
        return 

    def t_error(self, t):
        print("Illegal character '%s'" % t.value[0])
        t.lexer.skip(1)

    def token(self) -> Optional[lex.Token]:
        return self.lex.token()

# %% [markdown]
# # Building block of the program
#
# We need to maintain the current state of the program at each step, as we execute the instructions in the program one by one. This state is the collection of all the variables that have been defined till now. In our case the building block would be a QASM object, which will store the following variables
#
# 1. `supported_format` : boolean value that indicates whether or not the OPENQASM 3 statement has been defined in our program yet
# 2. `stdgates` : boolean value that indicates whether or not the include "stdgates.inc"; statement has been defined in the program
# 3. `qubits` : Dictionary that storee the name of the qubit registers and the count of qubits in each register
# 4. `bits` : Dictionary that storee the name of the bit registers and the count of bits in each register
# 5. `Circuit` : Stores the circuit made up till now

# %%
class Qasm:
    """Qasm stores the final result of the Qasm parsing."""

    def __init__(
        self, supported_format: bool, stdgates: bool, qubits: dict, bits: dict, c: Circuit
    ):
        # defines whether the Quantum Experience standard header
        # is present or not
        self.stdgates = stdgates
        # defines if it has a supported format or not
        self.supportedFormat = supported_format
        # circuit
        self.qubits = qubits
        self.bits = bits
        self.circuit = c

# %% [markdown]
# # Converting QASM Gates into Cirq Gates

# %%
class QasmGateStatement:
    """Specifies how to convert a call to an OpenQASM gate
    to a list of `cirq.GateOperation`s.
    Has the responsibility to validate the arguments
    and parameters of the call and to generate a list of corresponding
    `cirq.GateOperation`s in the `on` method.
    """

    def __init__(
        self,
        qasm_gate: str,
        cirq_gate: Union[ops.Gate, Callable[[List[float]], ops.Gate]],
        num_params: int,
        num_args: int,
    ):
        """Initializes a Qasm gate statement.
        Args:
            qasm_gate: the symbol of the QASM gate
            cirq_gate: the gate class on the cirq side
            num_args: the number of qubits (used in validation) this
                        gate takes
        """
        self.qasm_gate = qasm_gate
        self.cirq_gate = cirq_gate
        self.num_params = num_params

        # at least one quantum argument is mandatory for gates to act on
        assert num_args >= 1
        self.num_args = num_args

    # pylint: enable=missing-param-doc
    def _validate_args(self, args: List[List[ops.Qid]], lineno: int):
        if len(args) != self.num_args:
            raise QasmException(
                "{} only takes {} arg(s) (qubits and/or registers), "
                "got: {}, at line {}".format(self.qasm_gate, self.num_args, len(args), lineno)
            )

    def _validate_params(self, params: List[float], lineno: int):
        if len(params) != self.num_params:
            raise QasmException(
                "{} takes {} parameter(s), got: {}, at line {}".format(
                    self.qasm_gate, self.num_params, len(params), lineno
                )
            )

    def on(
        self, params: List[float], args: List[List[ops.Qid]], lineno: int
    ) -> Iterable[ops.Operation]:
        self._validate_args(args, lineno)
        self._validate_params(params, lineno)

        reg_sizes = np.unique([len(reg) for reg in args])
        if len(reg_sizes) > 2 or (len(reg_sizes) > 1 and reg_sizes[0] != 1):
            raise QasmException(
                f"Non matching quantum registers of length {reg_sizes} at line {lineno}"
            )

        # the actual gate we'll apply the arguments to might be a parameterized
        # or non-parameterized gate
        final_gate: ops.Gate = (
            self.cirq_gate if isinstance(self.cirq_gate, ops.Gate) else self.cirq_gate(params)
        )
        # OpenQASM gates can be applied on single qubits and qubit registers.
        # We represent single qubits as registers of size 1.
        # Based on the OpenQASM spec single qubit arguments can be mixed with qubit registers.
        # Given quantum registers of length reg_size and single qubits are both
        # used as arguments, we generate reg_size GateOperations via iterating
        # through each qubit of the registers 0 to n-1 and use the same one
        # qubit from the "single-qubit registers" for each operation.
        op_qubits = cast(Sequence[Sequence[ops.Qid]], functools.reduce(np.broadcast, args))
        for qubits in op_qubits:
            if isinstance(qubits, ops.Qid):
                yield final_gate.on(qubits)
            elif len(np.unique(qubits)) < len(qubits):
                raise QasmException(f"Overlapping qubits in arguments at line {lineno}")
            else:
                yield final_gate.on(*qubits)

# %% [markdown]
# # Parser

# %%
class OPENQASMParser():
    def __init__(self,file):
        # file containing OpenQASM code
        self.file = file
        self.lexer = OPENQASMLexer()
        self.parser = yacc.yacc(module=self, debug=False, write_tables=False)
        # parameters to be passed to the QASM class
        self.supported_format = False
        self.stdgatesinc = False
        self.qubits : Dict[str:int] = {}
        self.bits : Dict[str:int] = {}
        self.circuit = Circuit()
        self.variables : Dict[str:float] = {}
        # qubits are modelled as Qid
        self.qids: Dict[str, ops.Qid] = {}
        # gates described are X, Y, Z, RX, RY, RZ, H, S, S†, T, T†, CX, CCX, SWAP 
        # & CSWAP, as required
        self.gates = {
            'x': QasmGateStatement(qasm_gate='x', num_params=0, num_args=1, cirq_gate=ops.X),
            'y': QasmGateStatement(qasm_gate='y', num_params=0, num_args=1, cirq_gate=ops.Y),
            'z': QasmGateStatement(qasm_gate='z', num_params=0, num_args=1, cirq_gate=ops.Z),
            'h': QasmGateStatement(qasm_gate='h', num_params=0, num_args=1, cirq_gate=ops.H),
            's': QasmGateStatement(qasm_gate='s', num_params=0, num_args=1, cirq_gate=ops.S),
            't': QasmGateStatement(qasm_gate='t', num_params=0, num_args=1, cirq_gate=ops.T),  
            'cx': QasmGateStatement(qasm_gate='cx', num_params=0, num_args=2, cirq_gate=CX),
            'ccx': QasmGateStatement(qasm_gate='ccx', num_params=0, num_args=3, cirq_gate=ops.CCX),
            'swap': QasmGateStatement(qasm_gate='swap', num_params=0, num_args=2, cirq_gate=ops.SWAP),
            'cswap': QasmGateStatement(qasm_gate='cswap', num_params=0, num_args=3, cirq_gate=ops.CSWAP),
            'sdg': QasmGateStatement(qasm_gate='sdg', num_params=0, num_args=1, cirq_gate=ops.S ** -1),
            'tdg': QasmGateStatement(qasm_gate='tdg', num_params=0, num_args=1, cirq_gate=ops.T ** -1),
            'rx': QasmGateStatement(
                qasm_gate='rx', cirq_gate=(lambda params: ops.rx(params[0])), num_params=1, num_args=1
            ),
            'ry': QasmGateStatement(
                qasm_gate='ry', cirq_gate=(lambda params: ops.ry(params[0])), num_params=1, num_args=1
            ),
            'rz': QasmGateStatement(
                qasm_gate='rz', cirq_gate=(lambda params: ops.rz(params[0])), num_params=1, num_args=1
            ),
        }
        with open(file) as f:
            self.data = f.read()
        self.lexer.lex.input(self.data)
        self.parsedQasm = self.parser.parse(lexer=self.lexer)
    
    tokens = OPENQASMLexer.tokens
    start = 'start'

    # start : qasm
    def p_start(self,p):
        """start : qasm"""
        p[0] = p[1] 
    
    # qasm : qasm STDGATES
    #      | format
    #      | qasm circuit
    #      | empty
    def p_qasm_format_only(self, p):
        """qasm : format"""
        self.supported_format = True
        p[0] = Qasm(self.supported_format, self.stdgatesinc, self.qubits, self.bits, self.circuit)
        
    # format : FORMAT_SPEC
    def p_format(self, p):
        """format : FORMAT_SPEC"""
        if p[1] != "3":
            print("Incorrect format specified, ... overriding")
        else:
            print("Correct format specified")

    def p_include(self,p):
        """qasm : qasm STDGATES"""
        self.stdgatesinc=True
        p[0] = Qasm(self.supported_format, self.stdgatesinc, self.qubits, self.bits, self.circuit)

    def p_qasm_circuit(self,p):
        """qasm : qasm circuit"""
        p[0] = Qasm(self.supported_format,self.stdgatesinc,self.qubits,self.bits,p[2])

    # circuit : new_reg circuit
    #         | gate_op circuit
    #         | measurement circuit
    #         | variable_assign circuit
    #         | empty
    def p_circuit_reg(self,p):
        """circuit : new_reg circuit"""
        p[0] = self.circuit
    
    def p_circuit_gate(self, p):
        """circuit :  circuit gate_op"""
        self.circuit.append(p[2])
        p[0] = self.circuit

    def p_new_reg(self,p):
        """new_reg : QUBIT '[' NATURAL_NUMBER ']' ID ';'
        | BIT '[' NATURAL_NUMBER ']' ID ';'""" 
        name, length = p[5], p[3]
        if p[1] == "qubit":
            print(f'Qubit(s) with name: "{name}" and length "{length}"')
            self.qubits[name] = length
        else:
            print(f'Bit(s) with name: "{name}" and length "{length}"')
            self.bits[name] = length
        p[0] = (name,length)

    # def p_qasm_variable(self, p):
    #     """circuit : variable_assign circuit"""
    #     p[0] = self.circuit
    
    # def p_variable_assign(self,p):
    #     """variable_assign : ID ASSIGN NUMBER ';' variable_assign"""
    #     name, data = p[1], p[3]
    #     self.variables[name]=data
    #     print(f"{self.variables} has been added to variables")

    # gate_op : ID qargs
    #         | ID ( params ) qargs
    def p_gate_op_no_params(self, p):
        """gate_op :  ID qargs"""
        print(p[2], p[1])
        self.gate_operation(p[2], gate=p[1], p=p, params=[])
    
    def p_gate_op_with_params(self, p):
        """gate_op :  ID '(' params ')' qargs"""
        # print(p[3], p[1] , p[2])
        self.gate_operation(args=p[5], gate=p[1], p=p, params=p[3])
    
    def gate_operation(
        self, args: List[List[ops.Qid]], gate: str, p: Any, params: List[float]
    ):
        # assuming that stdgates has been included
        gate_set = self.gates
        if gate not in gate_set.keys():
            print("Unknown Gate: ", gate)
        p[0] = gate_set[gate].on(args=args, params=params, lineno=p.lineno(1))

    # qargs : qarg ',' qargs
    #      | qarg ';'
    def p_args_multiple(self, p):
        """qargs : qarg ',' qargs"""
        p[3].insert(0, p[1])
        p[0] = p[3]

    def p_args_single(self, p):
        """qargs : qarg ';'"""
        p[0] = [p[1]]

    def make_name(self, idx, reg):
        return str(reg) + "_" + str(idx)

    # qarg : ID
    #     | ID '[' NATURAL_NUMBER ']'
    def p_quantum_arg_register(self, p):
        """qarg : ID """
        reg = p[1]
        if reg not in self.qubits.keys():
            raise QasmException(f'Undefined quantum register "{reg}" at line {p.lineno(1)}')
        qids = []
        for idx in range(self.qubits[reg]):
            arg_name = self.make_name(idx, reg)
            if arg_name not in self.qids.keys():
                self.qids[arg_name] = NamedQubit(arg_name)
            qids.append(self.qids[arg_name])
        p[0] = qids
    
    def p_quantum_arg_bit(self, p):
        """qarg : ID '[' NATURAL_NUMBER ']' """
        reg = p[1]
        idx = p[3]
        arg_name = self.make_name(idx, reg)
        if reg not in self.qubits.keys():
            raise QasmException(f'Undefined quantum register "{reg}" at line {p.lineno(1)}')
        size = self.qubits[reg]
        if idx >= size:
            raise QasmException(
                'Out of bounds qubit index {} '
                'on register {} of size {} '
                'at line {}'.format(idx, reg, size, p.lineno(1))
            )
        if arg_name not in self.qids.keys():
            self.qids[arg_name] = NamedQubit(arg_name)
        p[0] = [self.qids[arg_name]]

    # params : param ',' params
    #        | param
    def p_params_multiple(self, p):
        """params : expr ',' params"""
        p[3].insert(0, p[1])
        p[0] = p[3]

    def p_params_single(self, p):
        """params : expr """
        p[0] = [p[1]]
    
    # expr : term
    #      | func '(' expression ')' """
    #      | binary_op
    #      | unary_op

    def p_expr_term(self, p):
        """expr : term"""
        p[0] = p[1]

    def p_expr_parens(self, p):
        """expr : '(' expr ')'"""
        p[0] = p[2]

    def p_expr_function_call(self, p):
        """expr : ID '(' expr ')'"""
        func = p[1]
        if func not in self.functions.keys():
            raise QasmException(f"Function not recognized: '{func}' at line {p.lineno(1)}")
        p[0] = self.functions[func](p[3])

    def p_expr_unary(self, p):
        """expr : '-' expr
        | '+' expr"""
        if p[1] == '-':
            p[0] = -p[2]
        else:
            p[0] = p[2]

    def p_expr_binary(self, p):
        """expr : expr '*' expr
        | expr '/' expr
        | expr '+' expr
        | expr '-' expr
        | expr '^' expr
        """
        p[0] = self.binary_operators[p[2]](p[1], p[3])

    def p_term(self, p):
        """term : NUMBER
        | NATURAL_NUMBER
        | PI"""
        p[0] = p[1]

    def p_circuit_empty(self, p):
        """circuit : empty"""
        p[0] = self.circuit

    # def p_variable_assign_empty(self, p):
    #     """variable_assign : empty"""
    #     print("Empty variable assign")

    def p_qasm_empty(self, p):
        """qasm : empty"""
        print("This is empty")

    # Acts as a sink
    def p_empty(self,p):
        """empty :"""
        pass

    # Basic error flagging
    def p_error(self, p):
        print("Error encountered")
        if p is None:
            print("p is none type")

# %% [markdown]
# # Custom Gates in Cirq
#
# Once I have built my circuit in Cirq after parsing the OpenQASM program, I need to find the hermitian of the circuit.
# For this \
# \
# Step 1: Find the unitary matrix corresponding to the entire circuit  \
# Step 2: Find the Hermitian matrix of the above computed unitary matrix \
# Step 3: Build a custom gate in Cirq from the hermitian matrix above and apply it on the qubits
#
# Hence for this I define a custom gate called `mygate` which will apply the Hermitian matrix on the qubits

# %%
class mygate(cirq.Gate):
    def __init__(self,qubits_num,unitary):
        super(mygate,self)
        self.qubits_num=qubits_num
        self.unitary=unitary

    def _num_qubits_(self):
        return self.qubits_num

    def _unitary_(self):
        return self.unitary

    def _circuit_diagram_info_(self,args):
        gates=[]
        for idx in range(self.qubits_num):
          gates.append("G"+str(idx))
        return tuple(gates)

# %% [markdown]
# # Conjugate Transpose of the circuit
#
# Since the entire circuit can be represented as 1 big unitary matrix, the conjugate transpose just means taking the hermitian of this unitary matrix and then applying this to the qubits.
#
# That is what the `herm_circuit` function does.

# %%
def herm_circuit(qubits,circuit):
    unitary=cirq.unitary(circuit)
    hermitian=unitary.conjugate()
    hermitian=hermitian.transpose()

    hermitian_gate=mygate(qubits,hermitian)
    return cirq.Circuit(hermitian_gate.on(*cirq.LineQid.for_gate(hermitian_gate)))

# %% [markdown]
# # Running the interpreter
#
# I have made a few demo .qasm files to test the interpreter

# %%
# if __name__=="__main__":
__file__ = "Task 3.ipynb"
parser = OPENQASMParser("test1.qasm")
circuit_properties=parser.parsedQasm
num_qubits=sum(list(circuit_properties.qubits.values()))
circuit=circuit_properties.circuit

print("\nRequired Circuit: ")
print("--------------------------------")
print(circuit)
print("--------------------------------")
print("\nHermitian Circuit: ")
print("--------------------------------")
print(herm_circuit(num_qubits,circuit))
print("--------------------------------")
# Out:
# include file encountered
# Correct format specified
# Qubit(s) with name: "q" and length "2"
# [[cirq.NamedQubit('q_0')]] x
# [[cirq.NamedQubit('q_1')]] h
# [[cirq.NamedQubit('q_0')], [cirq.NamedQubit('q_1')]] cx
#
# Required Circuit:
# --------------------------------
# q_0: ───X───@───
#             │
# q_1: ───H───X───
# --------------------------------
#
# Hermitian Circuit:
# --------------------------------
# 0 (d=2): ───G0───
#             │
# 1 (d=2): ───G1───
# --------------------------------
# WARNING: Token 'MEASURE' defined, but not used
# WARNING: There is 1 unused token

# %%
__file__ = "Task 3.ipynb"
parser = OPENQASMParser("test2.qasm")
circuit_properties=parser.parsedQasm
num_qubits=sum(list(circuit_properties.qubits.values()))

circuit=circuit_properties.circuit
hermitian_circuit=herm_circuit(num_qubits,circuit)

print("\nRequired Circuit: ")
print("--------------------------------")
print(circuit)
print("--------------------------------")
print("\nHermitian Circuit: ")
print("--------------------------------")
print(hermitian_circuit)
print("--------------------------------")
# Out:
# include file encountered
# Correct format specified
# Qubit(s) with name: "q" and length "2"
# [[cirq.NamedQubit('q_0')]] x
# [[cirq.NamedQubit('q_1')]] h
# [[cirq.NamedQubit('q_0')], [cirq.NamedQubit('q_1')]] cx
#
# Required Circuit:
# --------------------------------
# q_0: ───X───@───
#             │
# q_1: ───H───X───
# --------------------------------
#
# Hermitian Circuit:
# --------------------------------
# 0 (d=2): ───G0───
#             │
# 1 (d=2): ───G1───
# --------------------------------
# WARNING: Token 'MEASURE' defined, but not used
# WARNING: There is 1 unused token

# %%
print("Unitary matrix for the circuit")
print(circuit.unitary())

print ("-------------------")

print("Unitary matrix for the hermitian of the circuit")
print(hermitian_circuit.unitary())
# Out:
# Unitary matrix for the circuit
# [[ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.70710678+0.j]
#  [-0.        +0.j -0.        +0.j  0.70710678+0.j -0.70710678+0.j]
#  [ 0.70710678+0.j -0.70710678+0.j -0.        +0.j -0.        +0.j]
#  [ 0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]]
# -------------------
# Unitary matrix for the hermitian of the circuit
# [[ 0.        +0.j  0.        +0.j  0.70710678+0.j  0.70710678+0.j]
#  [ 0.        +0.j  0.        +0.j -0.70710678+0.j  0.70710678+0.j]
#  [ 0.70710678+0.j  0.70710678+0.j  0.        +0.j  0.        +0.j]
#  [ 0.70710678+0.j -0.70710678+0.j  0.        +0.j  0.        +0.j]]

# %% [markdown]
# # Test 2
#
# This test is to demonstrate that the hermitian circuit is being correctly generated. From the unitary matrices above we can clearly see that if we have $|01>$ state initially, then the actual circuit will output (-|10>+|11>)/sqrt(2), whereas the hermitian circuit will output the state (|10>-|11>)/sqrt(2).
#
# Step 1: Initialise the qubits and the circuit for the new state \
# Step 1: State Preparation : Apply the X gate to the q[1], then we now have |01> state \
# Step 3: Apply circuit : I have converted the entire circuit to a gate \
# Step 4: I apply the newly constructed gate on my qubits \
# Step 5: Simulate the circuit and get the output statevector

# %%
def final_statevector(circuit):
    result=sim.simulate(circuit)
    return np.around(result.final_state_vector,3)

# Step 1:
qubits=cirq.LineQubit.range(num_qubits)
circuit_new_state=Circuit()
hermitian_circuit_new_state=Circuit()

# Step 2:
circuit_new_state.append([cirq.X(qubits[1])])
hermitian_circuit_new_state.append([cirq.X(qubits[1])])

# Step 3:
circuit_gate=mygate(num_qubits,circuit.unitary())
hermitian_circuit_gate=mygate(num_qubits,hermitian_circuit.unitary())

# Step 4:
circuit_new_state.append(circuit_gate.on(*qubits))
hermitian_circuit_new_state.append(hermitian_circuit_gate.on(*qubits))

# Step 5:
print(circuit_new_state)
print(final_statevector(circuit_new_state))
print(hermitian_circuit_new_state)
print(final_statevector(hermitian_circuit_new_state))
# Out:
# 0: ───────G0───
#           │
# 1: ───X───G1───
# [ 0.   +0.j  0.   +0.j -0.707+0.j  0.707+0.j]
# 0: ───────G0───
#           │
# 1: ───X───G1───
# [ 0.   +0.j  0.   +0.j  0.707+0.j -0.707+0.j]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\github Projects\QOSF_Task3\Task 3.ipynb in <module>
#       3     ZZ_obs*=cirq.Z(qubits[idx])
#       4
# ----> 5 ev_list=sim.simulate_expectation_values(circuit,observables=ZZ_obs)
#       6 print(ev_list)
#
# ~\anaconda3\envs\cirq_work\lib\site-packages\cirq\sim\simulator.py in simulate_expectation_values(self, program, observables, param_resolver, qubit_order, initial_state, permit_terminal_measurements)
#     281             'permit_terminal_measurements' is False.
#     282         """
# --> 283         return self.simulate_expectation_values_sweep(
#     284             program,
#     285             observables,
#
# ~\anaconda3\envs\cirq_work\lib\site-packages\cirq\sim\simulator.py in simulate_expectation_values_sweep(self, program, observables, params, qubit_order, initial_state, permit_terminal_measurements)
#     303         Prefer overriding `simulate_expectation_values_sweep_iter`.
#     304         """
# --> 305         return list(
#     306             self.simulate_expectation_values_sweep_iter(
#     307                 program,
#
# ~\anaconda3\envs\cirq_work\lib\site-packages\cirq\sim\sparse_simulator.py in simulate_expectation_values_sweep_iter(self, program, observables, params, qubit_order, initial_state, permit_terminal_measurements)
#     232             observables = [observables]
#     233         pslist = [ops.PauliSum.wrap(pslike) for pslike in observables]
# --> 234         yield from (
#     235             [obs.expectation_from_state_vector(result.final_state_vector, qmap) for obs in pslist]
#     236             for result in self.simulate_sweep_iter(
#
# ~\anaconda3\envs\cirq_work\lib\site-packages\cirq\sim\sparse_simulator.py in <genexpr>(.0)
#     233         pslist = [ops.PauliSum.wrap(pslike) for pslike in observables]
#     234         yield from (
# --> 235             [obs.expectation_from_state_vector(result.final_state_vector, qmap) for obs in pslist]
#     236             for result in self.simulate_sweep_iter(
#     237                 program, params, qubit_order=qubit_order, initial_state=initial_state
#
# ~\anaconda3\envs\cirq_work\lib\site-packages\cirq\sim\sparse_simulator.py in <listcomp>(.0)
#     233         pslist = [ops.PauliSum.wrap(pslike) for pslike in observables]
#     234         yield from (
# --> 235             [obs.expectation_from_state_vector(result.final_state_vector, qmap) for obs in pslist]
#     236             for result in self.simulate_sweep_iter(
#     237                 program, params, qubit_order=qubit_order, initial_state=initial_state
#
# ~\anaconda3\envs\cirq_work\lib\site-packages\cirq\ops\linear_combinations.py in expectation_from_state_vector(self, state_vector, qubit_map, atol, check_preconditions)
#     535         size = state_vector.size
#     536         num_qubits = size.bit_length() - 1
# --> 537         _validate_qubit_mapping(qubit_map, self.qubits, num_qubits)
#     538
#     539         if len(state_vector.shape) != 1 and state_vector.shape != (2,) * num_qubits:
#
# ~\anaconda3\envs\cirq_work\lib\site-packages\cirq\ops\pauli_string.py in _validate_qubit_mapping(qubit_map, pauli_qubits, num_state_qubits)
#     961
#     962     if not set(qubit_map.keys()) >= set(pauli_qubits):
# --> 963         raise ValueError(
#     964             "Input qubit map must be a complete mapping over all of this PauliString's qubits."
#     965         )
#
# ValueError: Input qubit map must be a complete mapping over all of this PauliString's qubits.
